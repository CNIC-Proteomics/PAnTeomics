# %%
#
# Import modules
#

import numpy as np
import os
import pandas as pd
import requests
import time

# %%
#
# Set user input variables
#

pdmTable_path = r'C:\Users\rbarreror\home\Proteomics\GroupTools\pdmAPPRIS\PDMTable_1_Heart_PDMTable1.txt'
qcol = 'q'
ga = 'GRCm39'
organism = 'mus_musculus'

# %%
#
# Set constants
#

domain_table = 'appris_method.feather'

genome_assembly = {
    'homo_sapiens': 'GRCh38',
    'mus_musculus': 'GRCm39'
}

# %%
# Get Genome Assembly
if not organism in list(genome_assembly.keys()):
    print('** Organism not recognized or not available')

else:
    ga = genome_assembly[organism]

# %%
# Read pdm Table
df = pd.read_csv(pdmTable_path, sep='\t')

# %%
# Send request
ids = ','.join(df['q'].drop_duplicates().to_list())
fromdb = 'UniProtKB_AC-ID'
todb = 'Ensembl_Transcript'

url_map = 'https://rest.uniprot.org/idmapping/run'

r_url = requests.post(url_map, {
    'from': fromdb,
    'to': todb,
    'ids': ids
})

if not r_url.ok:
    print(f'** ERROR: {r_url.json()}')

else:
    print(f'** Mapping {fromdb} to {todb}')
# Out:
# ** Mapping UniProtKB_AC-ID to Ensembl_Transcript

# %%
# Get Ensembl id
while True:
    url_get = f'https://rest.uniprot.org/idmapping/stream/{r_url.json()["jobId"]}?compressed=false&format=json'
    r_mapped = requests.get(url_get)
    
    if r_mapped.ok:
        r_mapped = r_mapped.json()['results']
        break
    else:
        print(f'** Waiting map...')
        time.sleep(5)
# Out:
# ** Waiting map...
# ** Waiting map...
# ** Waiting map...
# ** Waiting map...

# %%
# Create dataframe mapping UniProt to Ensemble
mapdf = pd.DataFrame(
    [(i['from'], i['to']) for i in r_mapped],
    columns=['from', 'to']
)

# %%
# Get domain information
domdf = pd.read_feather(os.path.join('data', ga, domain_table))

# %%
# Relation table q -> domain
q_dom_df = pd.merge(
    mapdf,
    domdf,
    how='left',
    left_on='to',
    right_on='transcript_id'
)

# %%
# Dataframe containing pdm-q-pos (some pdm-q have the different pos)
pdm_qpos = df.loc[:, ['pdm', 'q']]
pdm_qpos['be'] = [list(zip(*[i.split(';'),j.split(';')])) for i,j in zip(df['b'].to_list(), df['e'].to_list())]
pdm_qpos = pdm_qpos.explode('be')
pdm_qpos['b'] = list(zip(*pdm_qpos['be'].to_list()))[0]
pdm_qpos['e'] = list(zip(*pdm_qpos['be'].to_list()))[1]
pdm_qpos = pdm_qpos.astype({'b':'int64', 'e':'int64'})

# %%
pdm_qpos_dom = pd.merge(
    pdm_qpos,
    q_dom_df,
    how='left',
    left_on='q',
    right_on='from'
)

# %%
# check if b or e is in (pep_start, pep_end) interval (it means intersection)
pdm_qpos_dom['intersect'] = np.logical_or(
    np.logical_and(
        pdm_qpos_dom['b']>pdm_qpos_dom['pep_start'],
        pdm_qpos_dom['b']<pdm_qpos_dom['pep_end']
    ),
    np.logical_and(
        pdm_qpos_dom['e']>pdm_qpos_dom['pep_start'],
        pdm_qpos_dom['e']<pdm_qpos_dom['pep_end']
    )
)

# %%
pdm_qpos_dom['be_domain'] = [(i,j) for i,j in zip(pdm_qpos_dom['pep_start'].to_list(), pdm_qpos_dom['pep_end'].to_list())]

# %%
pdm_dom = pdm_qpos_dom.loc[pdm_qpos_dom['intersect'], ['pdm', 'gene_id', 'hmm_name', 'be_domain']].drop_duplicates().groupby(['pdm','gene_id']).agg(list).reset_index()

# %%
df = pd.merge(
    df,
    pdm_dom,
    how='left',
    on='pdm'
)

# %%
os.path.splitext(pdmTable_path)[0]+'_APPRIS'+os.path.splitext(pdmTable_path)[1]
# Out:
# 'C:\\Users\\rbarreror\\home\\Proteomics\\GroupTools\\pdmAPPRIS\\PDMTable_1_Heart_PDMTable1_APPRIS.txt'

# %%
outfile = os.path.splitext(pdmTable_path)[0]+'_APPRIS'+os.path.splitext(pdmTable_path)[1]
df.to_csv(os.path.splitext(pdmTable_path)[0]+'_APPRIS.txt', sep='\t', index=False)

# %%
df
# Out:
#                          p                             pdm       q   qFreq  \
# 0                   IIIVGK                   IIIVGK_0.0002  P62342     1.0
# 1             SIAAEPIQGPYK             SIAAEPIQGPYK_0.0002  P28665   130.0
# 2          AGGVEHQQIIDIAQK          AGGVEHQQIIDIAQK_0.0002  Q9CZ13   730.0
# 3          ASYCIEHGDIEIAAK          ASYCIEHGDIEIAAK_0.0002  Q8CAQ8   485.0
# 4           AVEEQYSCEYGSGR           AVEEQYSCEYGSGR_0.0002  G5E902   415.0
# ...                    ...                             ...     ...     ...
# 31018     TYFPHFDVSHGSAQVK     TYFP[98.989064]HFDVSHGSAQVK  Q91VB8  3139.0
# 31019     TYFPHFDVSHGSAQVK     TYFP[98.989064]HFDVSHGSAQVK  Q91VB8  3139.0
# 31020  AAVDAGFVPNDMQVGQTGK  AAVDAGFVPNDMQ[98.989064]VGQTGK  Q99LC5  1241.0
# 31021     TYFPHFDVSHGSAQVK    TYFPHF[100.015501]DVSHGSAQVK  Q91VB8  3139.0
# 31022     TYFPHFDVSHGSAQVK    TYFPHF[100.015501]DVSHGSAQVK  Q91VB8  3139.0
#
#        pFreq                             pd           d  Missing_Cleavage  \
# 0        1.0                  IIIVGK:0.0002    0.000200               0.0
# 1        5.0            SIAAEPIQGPYK:0.0002    0.000200               0.0
# 2        1.0         AGGVEHQQIIDIAQK:0.0002    0.000200               0.0
# 3        1.0         ASYCIEHGDIEIAAK:0.0002    0.000200               0.0
# 4       12.0          AVEEQYSCEYGSGR:0.0002    0.000200               0.0
# ...      ...                            ...         ...               ...
# 31018  509.0     TYFPHFDVSHGSAQVK:98.989064   98.989064               0.0
# 31019  509.0     TYFPHFDVSHGSAQVK:98.989064   98.989064               0.0
# 31020  406.0  AAVDAGFVPNDMQVGQTGK:98.989064   98.989064               0.0
# 31021  509.0    TYFPHFDVSHGSAQVK:100.015501  100.015501               0.0
# 31022  509.0    TYFPHFDVSHGSAQVK:100.015501  100.015501               0.0
#
#        Truncated                     best_scan  ...  qfFreq  A     M     L  \
# 0            1.0  RH_Heart_TMTHF_FR5WO-98646-2  ...     1.0  U   NaN   NaN
# 1            1.0  RH_Heart_TMTHF_FR3WO-79252-3  ...     5.0  U   NaN   NaN
# 2            1.0  RH_Heart_TMTHF_FR5WO-75614-3  ...    45.0  U   NaN   NaN
# 3            1.0  RH_Heart_TMTHF_FR6WO-82593-3  ...     1.0  U   NaN   NaN
# 4            1.0  RH_Heart_TMTHF_FR3WO-49277-2  ...    12.0  U   NaN   NaN
# ...          ...                           ...  ...     ... ..   ...   ...
# 31018        0.0  RH_Heart_TMTHF_FR1WO-92752-3  ...   533.0  F   6.0  11.0
# 31019        0.0  RH_Heart_TMTHF_FR1WO-92752-3  ...   533.0  F   6.0  11.0
# 31020        0.0  RH_Heart_TMTHF_FR3WO-81696-3  ...   406.0  Q  13.0   7.0
# 31021        0.0  RH_Heart_TMTHF_FR1WO-91683-3  ...   533.0  F   6.0  11.0
# 31022        0.0  RH_Heart_TMTHF_FR1WO-91683-3  ...   533.0  F   6.0  11.0
#
#          N                    qdNA           qNA             gene_id  \
# 0      NaN        P62342:0.0002::U     P62342::U  ENSMUSG00000075700
# 1      NaN        P28665:0.0002::U     P28665::U  ENSMUSG00000059908
# 2      NaN        Q9CZ13:0.0002::U     Q9CZ13::U  ENSMUSG00000025651
# 3      NaN        Q8CAQ8:0.0002::U     Q8CAQ8::U  ENSMUSG00000052337
# 4      NaN        G5E902:0.0002::U     G5E902::U                 NaN
# ...    ...                     ...           ...                 ...
# 31018   47   Q91VB8:98.989064:47:F   Q91VB8:47:F  ENSMUSG00000069917
# 31019   47   Q91VB8:98.989064:47:F   Q91VB8:47:F  ENSMUSG00000069919
# 31020  262  Q99LC5:98.989064:262:Q  Q99LC5:262:Q  ENSMUSG00000032314
# 31021   47  Q91VB8:100.015501:47:F   Q91VB8:47:F  ENSMUSG00000069917
# 31022   47  Q91VB8:100.015501:47:F   Q91VB8:47:F  ENSMUSG00000069919
#
#                                 hmm_name  \
# 0                                  [Rdx]
# 1                                [A2M_N]
# 2                      [Peptidase_M16_C]
# 3      [Mitofilin, Mitofilin, Mitofilin]
# 4                                    NaN
# ...                                  ...
# 31018                           [Globin]
# 31019                           [Globin]
# 31020                        [ETF_alpha]
# 31021                           [Globin]
# 31022                           [Globin]
#
#                                            be_domain
# 0                                    [(42.0, 178.0)]
# 1                                   [(129.0, 221.0)]
# 2                                   [(211.0, 395.0)]
# 3      [(43.0, 745.0), (43.0, 734.0), (43.0, 697.0)]
# 4                                                NaN
# ...                                              ...
# 31018                                 [(7.0, 107.0)]
# 31019                                 [(7.0, 107.0)]
# 31020                               [(211.0, 293.0)]
# 31021                                 [(7.0, 107.0)]
# 31022                                 [(7.0, 107.0)]
#
# [31023 rows x 39 columns]

# %%
pdm_qpos_dom
# Out:
#                                    pdm       q          be    b    e    from  \
# 0                        IIIVGK_0.0002  P62342   (99, 104)   99  104  P62342
# 1                  SIAAEPIQGPYK_0.0002  P28665  (193, 204)  193  204  P28665
# 2                  SIAAEPIQGPYK_0.0002  P28665  (193, 204)  193  204  P28665
# 3                  SIAAEPIQGPYK_0.0002  P28665  (193, 204)  193  204  P28665
# 4                  SIAAEPIQGPYK_0.0002  P28665  (193, 204)  193  204  P28665
# ...                                ...     ...         ...  ...  ...     ...
# 106121     TYFP[98.989064]HFDVSHGSAQVK  Q91VB8    (42, 57)   42   57  Q91VB8
# 106122  AAVDAGFVPNDMQ[98.989064]VGQTGK  Q99LC5  (250, 268)  250  268  Q99LC5
# 106123  AAVDAGFVPNDMQ[98.989064]VGQTGK  Q99LC5  (250, 268)  250  268  Q99LC5
# 106124    TYFPHF[100.015501]DVSHGSAQVK  Q91VB8    (42, 57)   42   57  Q91VB8
# 106125    TYFPHF[100.015501]DVSHGSAQVK  Q91VB8    (42, 57)   42   57  Q91VB8
#
#                         to        evalue             gene_id        hmm_name  \
# 0       ENSMUST00000107924  6.800000e-16  ENSMUSG00000075700             Rdx
# 1       ENSMUST00000032228  1.700000e-18  ENSMUSG00000059908           A2M_N
# 2       ENSMUST00000032228  2.400000e-27  ENSMUSG00000059908         A2M_N_2
# 3       ENSMUST00000032228  3.400000e-28  ENSMUSG00000059908             A2M
# 4       ENSMUST00000032228  6.900000e-16  ENSMUSG00000059908  Thiol-ester_cl
# ...                    ...           ...                 ...             ...
# 106121  ENSMUST00000093209  4.500000e-29  ENSMUSG00000069919          Globin
# 106122  ENSMUST00000034866  3.300000e-41  ENSMUSG00000032314             ETF
# 106123  ENSMUST00000034866  8.400000e-38  ENSMUSG00000032314       ETF_alpha
# 106124  ENSMUST00000093207  4.500000e-29  ENSMUSG00000069917          Globin
# 106125  ENSMUST00000093209  4.500000e-29  ENSMUSG00000069919          Globin
#
#         pep_end  pep_start       transcript_id  intersect       be_domain
# 0         178.0       42.0  ENSMUST00000107924       True   (42.0, 178.0)
# 1         221.0      129.0  ENSMUST00000032228       True  (129.0, 221.0)
# 2         599.0      458.0  ENSMUST00000032228      False  (458.0, 599.0)
# 3         830.0      740.0  ENSMUST00000032228      False  (740.0, 830.0)
# 4         992.0      965.0  ENSMUST00000032228      False  (965.0, 992.0)
# ...         ...        ...                 ...        ...             ...
# 106121    107.0        7.0  ENSMUST00000093209       True    (7.0, 107.0)
# 106122    184.0       22.0  ENSMUST00000034866      False   (22.0, 184.0)
# 106123    293.0      211.0  ENSMUST00000034866       True  (211.0, 293.0)
# 106124    107.0        7.0  ENSMUST00000093207       True    (7.0, 107.0)
# 106125    107.0        7.0  ENSMUST00000093209       True    (7.0, 107.0)
#
# [106126 rows x 15 columns]

# %%
[list(zip(*[i.split(';'),j.split(';')])) for i,j in zip(df['b'].to_list(), df['e'].to_list())]
# Out:
# [[('99', '104')],
#  [('193', '204')],
#  [('234', '248')],
#  [('693', '707')],
#  [('46', '59')],
#  [('473', '485')],
#  [('333', '347')],
#  [('81', '95')],
#  [('42', '55')],
#  [('44', '54')],
#  [('123', '138')],
#  [('71', '81')],
#  [('347', '362')],
#  [('10', '21')],
#  [('234', '248')],
#  [('33', '48')],
#  [('63', '69')],
#  [('60', '73')],
#  [('22', '32')],
#  [('304', '314')],
#  [('410', '422')],
#  [('541', '553')],
#  [('81', '96')],
#  [('31', '41')],
#  [('13', '24')],
#  [('14', '42')],
#  [('715', '720')],
#  [('38', '51')],
#  [('84', '97')],
#  [('248', '264')],
#  [('87', '96')],
#  [('32', '48')],
#  [('62', '73')],
#  [('70', '80')],
#  [('79', '94')],
#  [('54', '65')],
#  [('61', '73')],
#  [('49', '62')],
#  [('31', '48')],
#  [('21', '31')],
#  [('40', '50')],
#  [('35', '43')],
#  [('136', '145')],
#  [('637', '649')],
#  [('37', '51')],
#  [('83', '97')],
#  [('22', '31')],
#  [('20', '32')],
#  [('34', '45')],
#  [('71', '86')],
#  [('56', '67')],
#  [('398', '415')],
#  [('46', '65')],
#  [('19', '32')],
#  [('380', '390')],
#  [('14', '26')],
#  [('135', '145')],
#  [('160', '177')],
#  [('123', '137')],
#  [('45', '56')],
#  [('32', '46')],
#  [('31', '48')],
#  [('31', '42')],
#  [('52', '62')],
#  [('604', '615')],
#  [('312', '322'),
#   ('411', '421'),
#   ('510', '520'),
#   ('576', '586'),
#   ('708', '718'),
#   ('939', '949')],
#  [('33', '50')],
#  [('11', '23')],
#  [('192', '203')],
#  [('403', '413')],
#  [('10', '26')],
#  [('11', '24')],
#  [('66', '87')],
#  [('340', '349')],
#  [('413', '426')],
#  [('142', '153')],
#  [('243', '257')],
#  [('189', '198')],
#  [('208', '217')],
#  [('2188', '2198')],
#  [('225', '236')],
#  [('335', '350')],
#  [('260', '271')],
#  [('178', '189')],
#  [('96', '113')],
#  [('853', '864')],
#  [('84', '94')],
#  [('151', '162')],
#  [('1647', '1670')],
#  [('158', '172')],
#  [('268', '275')],
#  [('1013', '1026')],
#  [('60', '73')],
#  [('163', '172')],
#  [('1605', '1614')],
#  [('141', '150')],
#  [('372', '387')],
#  [('268', '279')],
#  [('634', '648')],
#  [('528', '538')],
#  [('69', '83')],
#  [('144', '158')],
#  [('222', '233')],
#  [('238', '249')],
#  [('84', '96')],
#  [('206', '214')],
#  [('122', '132')],
#  [('28', '37')],
#  [('45', '55')],
#  [('294', '312')],
#  [('160', '171')],
#  [('325', '336')],
#  [('144', '154')],
#  [('8', '23')],
#  [('139', '152')],
#  [('306', '316')],
#  [('13', '23')],
#  [('482', '493')],
#  [('396', '408')],
#  [('324', '333')],
#  [('35', '44')],
#  [('192', '203')],
#  [('757', '767')],
#  [('155', '166')],
#  [('211', '223')],
#  [('930', '946')],
#  [('318', '325')],
#  [('190', '197')],
#  [('414', '426')],
#  [('261', '272')],
#  [('502', '510')],
#  [('33', '40')],
#  [('341', '360')],
#  [('240', '250')],
#  [('672', '682')],
#  [('59', '73')],
#  [('95', '114')],
#  [('399', '408')],
#  [('1227', '1242')],
#  [('656', '666')],
#  [('134', '146')],
#  [('1405', '1421')],
#  [('401', '413')],
#  [('11', '23')],
#  [('407', '424')],
#  [('347', '356')],
#  [('33', '50')],
#  [('204', '215')],
#  [('151', '163')],
#  [('418', '426')],
#  [('108', '116')],
#  [('34', '43')],
#  [('115', '130')],
#  [('853', '864')],
#  [('11', '25')],
#  [('140', '149')],
#  [('8', '22')],
#  [('852', '860')],
#  [('219', '249')],
#  [('318', '325')],
#  [('386', '396')],
#  [('696', '709')],
#  [('10', '18')],
#  [('500', '514')],
#  [('59', '73')],
#  [('604', '623')],
#  [('4427', '4439')],
#  [('79', '91')],
#  [('196', '204')],
#  [('144', '154')],
#  [('33', '41')],
#  [('41', '48')],
#  [('49', '62')],
#  [('320', '331')],
#  [('19', '31')],
#  [('59', '73')],
#  [('198', '209')],
#  [('312', '322'),
#   ('411', '421'),
#   ('510', '520'),
#   ('576', '586'),
#   ('708', '718'),
#   ('939', '949')],
#  [('130', '138')],
#  [('118', '138')],
#  [('59', '73')],
#  [('41', '53')],
#  [('68', '87')],
#  [('154', '165')],
#  [('90', '106')],
#  [('86', '106')],
#  [('48', '59')],
#  [('318', '332')],
#  [('47', '59')],
#  [('276', '301')],
#  [('70', '80')],
#  [('18', '32')],
#  [('265', '274')],
#  [('625', '640')],
#  [('51', '61')],
#  [('81', '97')],
#  [('95', '103')],
#  [('60', '76')],
#  [('581', '594')],
#  [('351', '361')],
#  [('27', '35')],
#  [('424', '451')],
#  [('59', '73')],
#  [('306', '316')],
#  [('35', '52')],
#  [('60', '75')],
#  [('82', '90')],
#  [('222', '233')],
#  [('106', '114')],
#  [('59', '73')],
#  [('18', '32')],
#  [('252', '264')],
#  [('84', '96')],
#  [('82', '90')],
#  [('228', '245')],
#  [('448', '457')],
#  [('6', '24')],
#  [('344', '358')],
#  [('102', '115')],
#  [('31', '43')],
#  [('116', '132')],
#  [('151', '165')],
#  [('81', '92')],
#  [('578', '587')],
#  [('327', '336')],
#  [('330', '343')],
#  [('307', '322')],
#  [('215', '253')],
#  [('552', '564')],
#  [('183', '197')],
#  [('177', '186')],
#  [('110', '119')],
#  [('112', '126')],
#  [('29', '37')],
#  [('252', '264')],
#  [('130', '140')],
#  [('189', '198')],
#  [('76', '89')],
#  [('852', '860')],
#  [('335', '350')],
#  [('88', '103')],
#  [('479', '491')],
#  [('137', '158')],
#  [('589', '601')],
#  [('59', '72')],
#  [('27', '38')],
#  [('187', '198')],
#  [('121', '135')],
#  [('4002', '4017')],
#  [('79', '91')],
#  [('40', '56')],
#  [('651', '660')],
#  [('13', '25')],
#  [('292', '301')],
#  [('51', '61')],
#  [('159', '168')],
#  [('960', '979')],
#  [('148', '163')],
#  [('237', '252')],
#  [('447', '462')],
#  [('447', '462')],
#  [('86', '106')],
#  [('86', '106')],
#  [('162', '173')],
#  [('138', '155')],
#  [('88', '102')],
#  [('158', '180')],
#  [('348', '359')],
#  [('638', '650')],
#  [('397', '411')],
#  [('137', '158')],
#  [('15', '27')],
#  [('266', '283')],
#  [('144', '157')],
#  [('10', '18')],
#  [('7', '21')],
#  [('92', '100')],
#  [('54', '68')],
#  [('691', '710')],
#  [('96', '113')],
#  [('207', '222')],
#  [('148', '163')],
#  [('342', '358')],
#  [('390', '404')],
#  [('86', '106')],
#  [('36', '46')],
#  [('252', '264')],
#  [('335', '350')],
#  [('240', '253')],
#  [('86', '99')],
#  [('233', '249')],
#  [('279', '287')],
#  [('251', '267')],
#  [('216', '229')],
#  [('75', '87')],
#  [('187', '200')],
#  [('216', '229')],
#  [('96', '113')],
#  [('134', '146')],
#  [('237', '252')],
#  [('191', '206')],
#  [('389', '406')],
#  [('48', '66')],
#  [('390', '404')],
#  [('108', '122')],
#  [('154', '165')],
#  [('389', '406')],
#  [('713', '727')],
#  [('79', '101')],
#  [('237', '249')],
#  [('181', '202')],
#  [('581', '594')],
#  [('86', '101')],
#  [('43', '55')],
#  [('85', '99')],
#  [('972', '990')],
#  [('98', '115')],
#  [('294', '314')],
#  [('133', '162')],
#  [('672', '688')],
#  [('686', '703')],
#  [('176', '194')],
#  [('46', '58')],
#  [('239', '254')],
#  [('208', '224')],
#  [('175', '189')],
#  [('625', '639')],
#  [('319', '328')],
#  [('321', '341')],
#  [('170', '187')],
#  [('625', '639')],
#  [('157', '169')],
#  [('535', '544')],
#  [('32', '41')],
#  [('1481', '1494')],
#  [('620', '637')],
#  [('265', '278')],
#  [('66', '79')],
#  [('298', '312')],
#  [('35', '47')],
#  [('1183', '1194')],
#  [('286', '296')],
#  [('342', '353')],
#  [('13', '25')],
#  [('122', '133')],
#  [('126', '137')],
#  [('853', '864')],
#  [('141', '150')],
#  [('108', '122')],
#  [('342', '353')],
#  [('1659', '1670')],
#  [('126', '142')],
#  [('186', '197')],
#  [('250', '260')],
#  [('225', '239')],
#  [('268', '287')],
#  [('221', '232')],
#  [('282', '296')],
#  [('407', '424')],
#  [('939', '950')],
#  [('78', '90')],
#  [('215', '227')],
#  [('78', '90')],
#  [('342', '353')],
#  [('225', '239')],
#  [('126', '137')],
#  [('250', '260')],
#  [('234', '245')],
#  [('479', '488')],
#  [('60', '71')],
#  [('95', '109')],
#  [('106', '119')],
#  [('57', '71')],
#  [('1382', '1399')],
#  [('81', '97')],
#  [('1280', '1291')],
#  [('9', '25')],
#  [('53', '63')],
#  [('528', '538')],
#  [('922', '934')],
#  [('35', '45')],
#  [('176', '186')],
#  [('337', '347')],
#  [('75', '88')],
#  [('60', '71')],
#  [('26', '40')],
#  [('330', '340')],
#  [('1329', '1339')],
#  [('108', '122')],
#  [('358', '369')],
#  [('42', '52')],
#  [('138', '148')],
#  [('542', '555')],
#  [('44', '58')],
#  [('610', '618')],
#  [('240', '250')],
#  [('1016', '1031')],
#  [('268', '279')],
#  [('75', '88')],
#  [('46', '59')],
#  [('42', '53')],
#  [('1096', '1108')],
#  [('650', '664')],
#  [('8', '23')],
#  [('90', '106')],
#  [('99', '112')],
#  [('469', '485')],
#  [('61', '77')],
#  [('147', '170')],
#  [('97', '121')],
#  [('241', '264')],
#  [('358', '379')],
#  [('237', '258')],
#  [('47', '75')],
#  [('153', '171')],
#  [('215', '234')],
#  [('325', '345')],
#  [('166', '188')],
#  [('61', '77')],
#  [('12', '25')],
#  [('177', '199')],
#  [('131', '152')],
#  [('516', '531')],
#  [('330', '347')],
#  [('190', '211')],
#  [('82', '101')],
#  [('102', '130')],
#  [('379', '403')],
#  [('566', '589')],
#  [('94', '119')],
#  [('38', '56')],
#  [('41', '73')],
#  [('188', '210')],
#  [('26', '40')],
#  [('180', '199')],
#  [('469', '485')],
#  [('46', '60')],
#  [('50', '67')],
#  [('335', '352')],
#  [('686', '719')],
#  [('379', '395')],
#  [('149', '171')],
#  [('71', '86')],
#  [('136', '151')],
#  [('48', '66')],
#  [('661', '676')],
#  [('138', '155')],
#  [('192', '209')],
#  [('472', '493')],
#  [('292', '306')],
#  [('166', '185')],
#  [('215', '232')],
#  [('346', '358')],
#  [('242', '269')],
#  [('98', '115')],
#  [('407', '422')],
#  [('83', '103')],
#  [('126', '142')],
#  [('53', '73')],
#  [('41', '54')],
#  [('32', '45')],
#  [('120', '134')],
#  [('143', '163')],
#  [('231', '249')],
#  [('153', '168')],
#  [('415', '427')],
#  [('43', '59')],
#  [('54', '68')],
#  [('134', '155')],
#  [('249', '262')],
#  [('63', '78')],
#  [('160', '179')],
#  [('159', '171')],
#  [('106', '119')],
#  [('12', '27')],
#  [('38', '55')],
#  [('499', '513')],
#  [('61', '73')],
#  [('265', '279')],
#  [('123', '149')],
#  [('136', '148')],
#  [('69', '84')],
#  [('211', '223')],
#  [('617', '633')],
#  [('461', '489')],
#  [('67', '81')],
#  [('292', '305')],
#  [('133', '149')],
#  [('213', '227')],
#  [('18', '35')],
#  [('228', '254')],
#  [('342', '358')],
#  [('79', '91')],
#  [('146', '173')],
#  [('28140', '28155')],
#  [('13', '25')],
#  [('421', '439')],
#  [('118', '129')],
#  [('43', '57')],
#  [('503', '517')],
#  [('366', '380')],
#  [('118', '130')],
#  [('708', '726')],
#  [('390', '404')],
#  [('884', '897')],
#  [('361', '374')],
#  [('293', '307')],
#  [('93', '106')],
#  [('78', '95')],
#  [('427', '438')],
#  [('190', '202')],
#  [('151', '165')],
#  [('250', '267')],
#  [('60', '75')],
#  [('110', '128')],
#  [('406', '417')],
#  [('76', '89')],
#  [('88', '102')],
#  [('60', '73')],
#  [('158', '176')],
#  [('287', '298')],
#  [('62', '72')],
#  [('528', '543')],
#  [('76', '88')],
#  [('35', '51')],
#  [('344', '358')],
#  [('624', '637')],
#  [('310', '331')],
#  [('194', '208')],
#  [('164', '179')],
#  [('29', '42')],
#  [('119', '148')],
#  [('384', '409')],
#  [('58', '73')],
#  [('37', '49')],
#  [('225', '236')],
#  [('277', '288')],
#  [('7', '17')],
#  [('172', '183')],
#  [('271', '282')],
#  [('212', '226')],
#  [('263', '275')],
#  [('170', '187')],
#  [('116', '132')],
#  [('480', '491')],
#  [('225', '239')],
#  [('2044', '2054')],
#  [('1319', '1329')],
#  [('62', '78')],
#  [('133', '144')],
#  [('606', '628')],
#  [('103', '117')],
#  [('44', '63')],
#  [('13', '23')],
#  [('299', '309')],
#  [('665', '681')],
#  [('941', '953')],
#  [('122', '133')],
#  [('321', '341')],
#  [('680', '702')],
#  [('126', '137')],
#  [('355', '375')],
#  [('457', '469')],
#  [('46', '58')],
#  [('132', '142')],
#  [('66', '75')],
#  [('309', '320')],
#  [('158', '180')],
#  [('519', '542')],
#  [('767', '786')],
#  [('7', '18'), ('122', '133')],
#  [('853', '864')],
#  [('331', '345')],
#  [('100', '111')],
#  [('98', '113')],
#  [('90', '106')],
#  [('107', '114')],
#  [('339', '350')],
#  [('503', '515')],
#  [('215', '227')],
#  [('32', '44')],
#  [('200', '210')],
#  [('178', '204')],
#  [('106', '117')],
#  [('308', '318')],
#  [('169', '181')],
#  [('442', '453')],
#  [('131', '142')],
#  [('528', '538')],
#  [('224', '236')],
#  [('1477', '1488')],
#  [('30', '41')],
#  [('122', '132')],
#  [('203', '218')],
#  [('96', '111')],
#  [('278', '287')],
#  [('108', '132')],
#  [('97', '108')],
#  [('390', '414')],
#  [('376', '388')],
#  [('73', '89')],
#  [('45', '64')],
#  [('26470', '26488')],
#  [('68', '79')],
#  [('55', '86')],
#  [('147', '157')],
#  [('539', '550')],
#  [('304', '323')],
#  [('30', '42')],
#  [('1465', '1474')],
#  [('619', '630')],
#  [('58', '70')],
#  [('509', '523')],
#  [('77', '87')],
#  [('27', '39')],
#  [('464', '487')],
#  [('650', '659')],
#  [('71', '84')],
#  [('255', '266')],
#  [('40', '50')],
#  [('1110', '1125')],
#  [('242', '251')],
#  [('51', '67')],
#  [('5', '16')],
#  [('795', '814')],
#  [('700', '710')],
#  [('407', '419')],
#  [('634', '648')],
#  [('575', '586')],
#  [('258', '270')],
#  [('407', '433')],
#  [('337', '363')],
#  [('222', '234')],
#  [('579', '596')],
#  [('145', '164')],
#  [('212', '222')],
#  [('2070', '2084')],
#  [('405', '415')],
#  [('77', '97')],
#  [('513', '529')],
#  [('19', '31')],
#  [('42', '60')],
#  [('686', '703')],
#  [('45', '59')],
#  [('79', '101')],
#  [('130', '138')],
#  [('238', '249')],
#  [('590', '597')],
#  [('1451', '1462')],
#  [('153', '163')],
#  [('106', '116')],
#  [('401', '413')],
#  [('693', '715')],
#  [('342', '353')],
#  [('29', '38')],
#  [('137', '150')],
#  [('11', '32')],
#  [('101', '112')],
#  [('113', '127')],
#  [('173', '199')],
#  [('436', '446')],
#  [('729', '739')],
#  [('387', '399')],
#  [('410', '427')],
#  [('361', '382')],
#  [('32', '41')],
#  [('83', '111')],
#  [('533', '552')],
#  [('20', '30')],
#  [('81', '97')],
#  [('149', '173')],
#  [('99', '112')],
#  [('49', '58')],
#  [('360', '373')],
#  [('109', '119')],
#  [('188', '203')],
#  [('248', '259')],
#  [('98', '109')],
#  [('1302', '1314')],
#  [('69', '79')],
#  [('263', '276')],
#  [('171', '185')],
#  [('19', '31')],
#  [('358', '370')],
#  [('540', '551')],
#  [('100', '111')],
#  [('85', '97')],
#  [('103', '121')],
#  [('183', '196')],
#  [('140', '155')],
#  [('140', '149')],
#  [('125', '134')],
#  [('704', '717')],
#  [('203', '228')],
#  [('36', '54')],
#  [('110', '119')],
#  [('772', '785')],
#  [('1024', '1037')],
#  [('373', '387')],
#  [('173', '184')],
#  [('552', '565')],
#  [('422', '432')],
#  [('79', '88')],
#  [('142', '150')],
#  [('1625', '1637')],
#  [('107', '133')],
#  [('146', '162')],
#  [('153', '164')],
#  [('163', '177')],
#  [('484', '498')],
#  [('300', '309')],
#  [('470', '494')],
#  [('221', '229')],
#  [('192', '200')],
#  [('876', '889')],
#  [('270', '281')],
#  [('48', '59')],
#  [('24', '41')],
#  [('327', '338')],
#  [('82', '92')],
#  [('206', '214')],
#  [('360', '375')],
#  [('84', '96')],
#  [('227', '248')],
#  [('80', '98')],
#  [('355', '370')],
#  [('1805', '1816')],
#  [('189', '200')],
#  [('250', '268')],
#  [('21', '33')],
#  [('129', '144')],
#  [('8', '23')],
#  [('195', '204')],
#  [('118', '138')],
#  [('334', '343')],
#  [('417', '432')],
#  [('60', '71')],
#  [('220', '232')],
#  [('69', '80')],
#  [('116', '129')],
#  [('16', '26')],
#  [('462', '475')],
#  [('172', '188')],
#  [('228', '240')],
#  [('397', '415')],
#  [('256', '265')],
#  [('132', '148')],
#  [('125', '139')],
#  [('114', '129')],
#  [('159', '175')],
#  [('870', '885')],
#  [('6', '30')],
#  [('82', '94')],
#  [('35', '53')],
#  [('187', '198')],
#  [('196', '214')],
#  [('349', '358')],
#  [('454', '469')],
#  [('1776', '1785')],
#  [('2097', '2111')],
#  [('77', '85')],
#  [('11', '22')],
#  [('173', '183')],
#  [('301', '312')],
#  [('192', '200')],
#  [('189', '202')],
#  [('281', '295')],
#  [('176', '187')],
#  [('3497', '3512')],
#  [('421', '432')],
#  [('152', '161')],
#  [('555', '568')],
#  [('278', '292')],
#  [('59', '72')],
#  [('45', '56')],
#  [('92', '102')],
#  [('69', '80')],
#  [('620', '637')],
#  [('42', '60')],
#  [('44', '65')],
#  [('1935', '1944')],
#  [('141', '150')],
#  [('59', '73')],
#  [('68', '79')],
#  [('1073', '1082')],
#  [('1984', '1995')],
#  [('178', '189')],
#  [('28', '39')],
#  [('53', '74')],
#  [('175', '188')],
#  [('153', '169')],
#  [('375', '393')],
#  [('819', '836')],
#  [('99', '111')],
#  [('89', '105'), ('204', '220')],
#  [('137', '158')],
#  [('70', '86')],
#  [('20', '42')],
#  [('726', '736')],
#  [('133', '145')],
#  [('41', '52')],
#  [('870', '880')],
#  [('31', '41')],
#  [('51', '61')],
#  [('1268', '1279')],
#  [('238', '257')],
#  [('9', '42')],
#  [('53', '67')],
#  [('989', '999')],
#  [('1131', '1141')],
#  [('1854', '1867')],
#  [('562', '574')],
#  [('48', '64')],
#  [('254', '268')],
#  [('287', '297')],
#  [('52', '76')],
#  [('64', '77')],
#  [('5', '23')],
#  [('2692', '2700')],
#  [('215', '247')],
#  [('535', '549')],
#  [('1481', '1494')],
#  [('71', '85')],
#  [('509', '521')],
#  [('18', '32')],
#  [('16', '28')],
#  [('65', '80')],
#  [('1238', '1264')],
#  [('478', '495')],
#  [('239', '249')],
#  [('145', '154')],
#  [('43', '57')],
#  [('330', '342')],
#  [('239', '254')],
#  [('607', '615')],
#  [('224', '233')],
#  [('67', '81')],
#  [('268', '281')],
#  [('20', '29')],
#  [('344', '358')],
#  [('648', '658')],
#  [('183', '193')],
#  [('230', '249')],
#  [('250', '263')],
#  [('240', '250')],
#  [('392', '410')],
#  [('127', '139')],
#  [('144', '151')],
#  [('147', '155')],
#  [('329', '340')],
#  [('214', '224')],
#  [('56', '67')],
#  [('60', '71')],
#  [('625', '639')],
#  [('53', '65')],
#  [('77', '92')],
#  [('47', '58')],
#  [('169', '190')],
#  [('59', '71')],
#  [('370', '384')],
#  [('181', '195')],
#  [('183', '192')],
#  [('655', '669')],
#  [('1070', '1088')],
#  [('292', '303')],
#  [('406', '418')],
#  [('19', '43')],
#  [('33', '47')],
#  [('257', '269')],
#  [('245', '254')],
#  [('270', '284')],
#  [('190', '198')],
#  [('1801', '1810')],
#  [('221', '230')],
#  [('340', '348')],
#  [('170', '180')],
#  [('86', '98')],
#  [('316', '326')],
#  [('507', '517')],
#  [('240', '253')],
#  [('115', '128')],
#  [('335', '347')],
#  [('585', '596')],
#  [('367', '377')],
#  [('63', '91')],
#  [('86', '105')],
#  [('13959', '13973')],
#  [('259', '274')],
#  [('184', '191')],
#  [('1300', '1312')],
#  [('90', '104')],
#  [('571', '582')],
#  [('114', '125')],
#  [('59', '69')],
#  [('344', '357')],
#  [('134', '146')],
#  [('8', '20')],
#  [('139', '148')],
#  [('531', '567')],
#  [('256', '269')],
#  [('143', '154')],
#  [('92', '102')],
#  [('39', '51')],
#  [('589', '602')],
#  [('93', '110')],
#  [('35', '47')],
#  [('259', '279')],
#  [('214', '222')],
#  [('87', '94')],
#  [('177', '188')],
#  [('440', '449')],
#  [('396', '407')],
#  [('172', '184')],
#  [('1703', '1714')],
#  [('1363', '1384')],
#  [('643', '659')],
#  [('468', '480')],
#  [('166', '182')],
#  [('183', '192')],
#  [('153', '164')],
#  [('943', '952')],
#  [('380', '394')],
#  [('374', '383')],
#  [('223', '233')],
#  [('3345', '3356'), ('3473', '3484'), ('4445', '4456')],
#  [('8', '23')],
#  [('209', '218')],
#  [('244', '255')],
#  [('182', '198')],
#  [('11', '26')],
#  [('172', '183')],
#  [('337', '347')],
#  [('108', '116')],
#  [('69', '83')],
#  [('41', '53')],
#  [('506', '516')],
#  [('242', '257')],
#  [('191', '203')],
#  [('471', '479')],
#  [('571', '583')],
#  [('325', '333')],
#  [('1016', '1031')],
#  [('38', '49')],
#  [('67', '80')],
#  [('331', '338')],
#  [('26', '38')],
#  [('238', '248')],
#  [('419', '439')],
#  [('91', '107')],
#  [('90', '100')],
#  [('22', '32')],
#  [('39', '46')],
#  [('17', '27')],
#  [('299', '310')],
#  [('628', '642')],
#  [('59', '70')],
#  [('592', '605')],
#  [('305', '313')],
#  [('831', '847')],
#  [('65', '86')],
#  [('213', '226')],
#  [('105', '117')],
#  [('91', '102')],
#  [('110', '118')],
#  [('122', '133')],
#  [('413', '422')],
#  [('530', '538')],
#  [('159', '171')],
#  [('286', '296')],
#  [('889', '905')],
#  [('179', '188')],
#  [('337', '348')],
#  [('832', '841')],
#  [('136', '149')],
#  [('142', '152')],
#  [('604', '615')],
#  [('266', '289')],
#  [('1625', '1641')],
#  [('482', '493')],
#  [('171', '180')],
#  [('210', '220')],
#  [('591', '601')],
#  [('466', '480')],
#  [('76', '90')],
#  [('167', '181')],
#  [('36', '53')],
#  [('172', '183')],
#  [('255', '267')],
#  [('441', '450')],
#  [('398', '414')],
#  [('373', '387')],
#  [('50', '64')],
#  [('73', '85')],
#  [('143', '161')],
#  [('37', '55')],
#  [('292', '301')],
#  [('518', '528')],
#  [('183', '191')],
#  [('64', '73')],
#  [('206', '218')],
#  ...]

# %%
[i for i in df['e'].to_list() if ';' in i]
# Out:
# ['322;421;520;586;718;949',
#  '322;421;520;586;718;949',
#  '18;133',
#  '105;220',
#  '3356;3484;4456',
#  '245;344;443;476;509;608;641;839',
#  '539;712;1048;1219;1392;1565',
#  '223;454;487;619;817',
#  '114;229',
#  '481;490;499;508;553',
#  '1949;2016;2083;2150',
#  '355;652;850',
#  '1074;1478',
#  '741;785',
#  '2904;3612;3866;3992;4584',
#  '674;740;773;938',
#  '1286;1412;1859;2262;2531;2659;2785;2913;3493;3621;3875;4001;4129;4593',
#  '1816;2219',
#  '628;654',
#  '562;571;580',
#  '322;421;520;586;718;949',
#  '1538;1664;3365;4465',
#  '774;1403;1850;2253;2522;2776;3738;4120',
#  '774;1403;1850;2253;2522;2776;3738;4120',
#  '105;220',
#  '105;220',
#  '674;740;773;938',
#  '774;1403;1850;2253;2522;2776;3738;4120',
#  '105;220',
#  '105;220',
#  '105;220',
#  '1949;2016;2083;2150',
#  '105;220',
#  '223;454;487;619;817',
#  '410;575;905',
#  '18;133',
#  '18;133',
#  '18;133',
#  '245;344;443;476;509;608;641;839',
#  '1949;2016;2083;2150',
#  '774;1403;1850;2253;2522;2776;3738;4120',
#  '245;344;443;476;509;608;641;839',
#  '539;712;1048;1219;1392;1565',
#  '1302;2547;2675;2801;2929;3381;3509;3637;3763;3891;4145;4481',
#  '1816;2219',
#  '18;133',
#  '1342;2589;2715;3295;3423;3551;3677;3931;4059;4395;4523',
#  '355;652;850',
#  '941;1033;1125;1217;1309;1493;1585;1677;1769;1861;1953;2137',
#  '105;220',
#  '18;133',
#  '774;1403;1850;2253;2522;2776;3738;4120',
#  '154;281',
#  '18;133',
#  '105;220',
#  '245;344;443;476;509;608;641;839',
#  '105;220',
#  '4150;4238;4326;4502;4590',
#  '708;827;1775;1977;2044;2111;2178',
#  '105;220',
#  '289;685;883',
#  '388;553',
#  '114;229',
#  '114;229',
#  '105;220',
#  '105;220',
#  '105;220',
#  '105;220',
#  '1302;2547;2675;2801;2929;3381;3509;3637;3763;3891;4145;4481',
#  '105;220',
#  '105;220',
#  '245;344;443;476;509;608;641;839',
#  '245;344;443;476;509;608;641;839',
#  '774;1403;1850;2253;2522;2776;3738;4120',
#  '18;133',
#  '105;220',
#  '18;133',
#  '18;133',
#  '1376;2749;3711',
#  '114;229',
#  '2904;3612;3866;3992;4584',
#  '105;220',
#  '105;220',
#  '105;220',
#  '105;220',
#  '105;220',
#  '322;421;520;586;718;949',
#  '169;180']

# %%
q_dom_df
# Out:
#             from                  to        evalue             gene_id  \
# 0         P62342  ENSMUST00000107924  6.800000e-16  ENSMUSG00000075700
# 1         P28665  ENSMUST00000032228  1.700000e-18  ENSMUSG00000059908
# 2         P28665  ENSMUST00000032228  2.400000e-27  ENSMUSG00000059908
# 3         P28665  ENSMUST00000032228  3.400000e-28  ENSMUSG00000059908
# 4         P28665  ENSMUST00000032228  6.900000e-16  ENSMUSG00000059908
# ...          ...                 ...           ...                 ...
# 8429  A0A0R4IZX1  ENSMUST00000002327  5.800000e-19  ENSMUSG00000002257
# 8430      P51860  ENSMUST00000121720  4.600000e-85  ENSMUSG00000082229
# 8431      E9QK89  ENSMUST00000082337  1.300000e-11  ENSMUSG00000061607
# 8432      E9QK89  ENSMUST00000082337  3.800000e-08  ENSMUSG00000061607
# 8433      Q0ZCJ7  ENSMUST00000148532  1.100000e-09  ENSMUSG00000042918
#
#             hmm_name  pep_end  pep_start       transcript_id
# 0                Rdx    178.0       42.0  ENSMUST00000107924
# 1              A2M_N    221.0      129.0  ENSMUST00000032228
# 2            A2M_N_2    599.0      458.0  ENSMUST00000032228
# 3                A2M    830.0      740.0  ENSMUST00000032228
# 4     Thiol-ester_cl    992.0      965.0  ENSMUST00000032228
# ...              ...      ...        ...                 ...
# 8429              PH    312.0      217.0  ENSMUST00000002327
# 8430             NAP    411.0      111.0  ENSMUST00000121720
# 8431             FHA    123.0       55.0  ENSMUST00000082337
# 8432   RTT107_BRCT_5   1587.0     1499.0  ENSMUST00000082337
# 8433             SAP    194.0      166.0  ENSMUST00000148532
#
# [8434 rows x 8 columns]

# %%
df.loc[:, ['pdm', 'q', 'b', 'e']]
# Out:
#                                   pdm       q    b    e
# 0                       IIIVGK_0.0002  P62342   99  104
# 1                 SIAAEPIQGPYK_0.0002  P28665  193  204
# 2              AGGVEHQQIIDIAQK_0.0002  Q9CZ13  234  248
# 3              ASYCIEHGDIEIAAK_0.0002  Q8CAQ8  693  707
# 4               AVEEQYSCEYGSGR_0.0002  G5E902   46   59
# ...                               ...     ...  ...  ...
# 30043     TYFPHF[98.989064]DVSHGSAQVK  Q91VB8   42   57
# 30044      HSGDFGADAQGA[98.989064]MSK  P04247  120  134
# 30045     TYFP[98.989064]HFDVSHGSAQVK  Q91VB8   42   57
# 30046  AAVDAGFVPNDMQ[98.989064]VGQTGK  Q99LC5  250  268
# 30047    TYFPHF[100.015501]DVSHGSAQVK  Q91VB8   42   57
#
# [30048 rows x 4 columns]

# %%
domdf
# Out:
#                   evalue             gene_id         hmm_name pep_end  \
# 0                3.6e-36  ENSMUSG00000042046      Pkinase_Tyr     897
# 1                2.7e-27  ENSMUSG00000042046          Pkinase     820
# 2             0.00000019  ENSMUSG00000070524             Ig_2     100
# 3         0.000000000033  ENSMUSG00000070524             Ig_2     190
# 4                4.4e-42  ENSMUSG00000048495          Cupin_8     253
# ...                  ...                 ...              ...     ...
# 110001           8.8e-41  ENSMUSG00000064357       ATP-synt_A     222
# 110002          8.6e-105  ENSMUSG00000064341           NADHdh     303
# 110003  0.00000000000022  ENSMUSG00000064367  Proton_antipo_N     121
# 110004           2.8e-74  ENSMUSG00000064367  Proton_antipo_M     418
# 110005           1.7e-53  ENSMUSG00000064367          NADH5_C     601
#
#        pep_start       transcript_id
# 0            652  ENSMUST00000045110
# 1            653  ENSMUST00000188389
# 2             22  ENSMUST00000094337
# 3            105  ENSMUST00000094337
# 4             17  ENSMUST00000162686
# ...          ...                 ...
# 110001        19  ENSMUST00000082408
# 110002         5  ENSMUST00000082392
# 110003        66  ENSMUST00000082418
# 110004       134  ENSMUST00000082418
# 110005       422  ENSMUST00000082418
#
# [110006 rows x 6 columns]

# %%
mapdf
# Out:
#             from                  to
# 0         P62342  ENSMUSG00000075700
# 1         P28665  ENSMUSG00000059908
# 2         Q9CZ13  ENSMUSG00000025651
# 3         Q8CAQ8  ENSMUSG00000052337
# 4         G5E902  ENSMUSG00000061904
# ...          ...                 ...
# 2721  A0A1D5RLV3  ENSMUSG00000055567
# 2722  A0A0R4IZX1  ENSMUSG00000002257
# 2723      P51860  ENSMUSG00000082229
# 2724      E9QK89  ENSMUSG00000061607
# 2725      Q0ZCJ7  ENSMUSG00000042918
#
# [2726 rows x 2 columns]

# %%
# Get domain information from APPRIS
toids = mapdf['to'].drop_duplicates().to_list()

url_appris_pre = f'https://apprisws.bioinfo.cnio.es/rest/exporter/id/{organism}/'
url_appris_suf = f'?methods=spade&format=json&as={ga}&sc=ensembl&ds=e105v46'

r_appris = [requests.get(url_appris_pre+i+url_appris_suf) for i in toids[:10]]

# %%
import json
json.loads('{"a":"aa"}')
# Out:
# {'a': 'aa'}

# %%
[
    m for m in 
    [
        (k['gene_id'], k['transcript_id'], *[l.split(':')[1] for l in k['note'].split(',')]) for j in
        [
            i.json() for i in r_appris if i.ok # get response from appris
        ]
        for k in j if all(np.isin(['gene_id', 'transcript_id', 'note'], list(k.keys())))
    ] if len(m)==6
]
# Out:
# [('ENSMUSG00000075700', 'ENSMUST00000107924', 'Rdx', '6.8e-16', '42', '178'),
#  ('ENSMUSG00000059908',
#   'ENSMUST00000032228',
#   'A2M_N',
#   '1.7e-18',
#   '129',
#   '221'),
#  ('ENSMUSG00000059908',
#   'ENSMUST00000032228',
#   'A2M_N_2',
#   '2.4e-27',
#   '458',
#   '599'),
#  ('ENSMUSG00000059908', 'ENSMUST00000032228', 'A2M', '3.4e-28', '740', '830'),
#  ('ENSMUSG00000059908',
#   'ENSMUST00000032228',
#   'Thiol-ester_cl',
#   '6.9e-16',
#   '965',
#   '992'),
#  ('ENSMUSG00000059908',
#   'ENSMUST00000032228',
#   'A2M_comp',
#   '2.3e-91',
#   '1013',
#   '1267'),
#  ('ENSMUSG00000059908',
#   'ENSMUST00000032228',
#   'A2M_recep',
#   '2.3e-26',
#   '1378',
#   '1465'),
#  ('ENSMUSG00000025651',
#   'ENSMUST00000194047',
#   'Peptidase_M16',
#   '4.2e-53',
#   '41',
#   '187'),
#  ('ENSMUSG00000025651',
#   'ENSMUST00000026743',
#   'Peptidase_M16',
#   '4.2e-53',
#   '58',
#   '204'),
#  ('ENSMUSG00000025651',
#   'ENSMUST00000026743',
#   'Peptidase_M16_C',
#   '9e-32',
#   '211',
#   '395'),
#  ('ENSMUSG00000025651',
#   'ENSMUST00000194469',
#   'Peptidase_M16_C',
#   '6.2e-09',
#   '3',
#   '94'),
#  ('ENSMUSG00000052337',
#   'ENSMUST00000166975',
#   'Mitofilin',
#   '1.3e-20',
#   '43',
#   '134'),
#  ('ENSMUSG00000052337',
#   'ENSMUST00000166975',
#   'Mitofilin',
#   '1.9e-78',
#   '138',
#   '466'),
#  ('ENSMUSG00000052337',
#   'ENSMUST00000171057',
#   'Mitofilin',
#   '2.7e-24',
#   '43',
#   '180'),
#  ('ENSMUSG00000052337',
#   'ENSMUST00000101301',
#   'Mitofilin',
#   '1.2e-206',
#   '43',
#   '734'),
#  ('ENSMUSG00000052337',
#   'ENSMUST00000207003',
#   'Mitofilin',
#   '3.2e-107',
#   '43',
#   '467'),
#  ('ENSMUSG00000052337',
#   'ENSMUST00000205628',
#   'Mitofilin',
#   '6.4e-97',
#   '2',
#   '243'),
#  ('ENSMUSG00000052337',
#   'ENSMUST00000165331',
#   'Mitofilin',
#   '6.8e-37',
#   '43',
#   '254'),
#  ('ENSMUSG00000052337',
#   'ENSMUST00000114151',
#   'Mitofilin',
#   '1e-209',
#   '43',
#   '697'),
#  ('ENSMUSG00000052337',
#   'ENSMUST00000166938',
#   'Mitofilin',
#   '1.3e-20',
#   '43',
#   '134'),
#  ('ENSMUSG00000052337',
#   'ENSMUST00000166938',
#   'Mitofilin',
#   '7e-175',
#   '138',
#   '667'),
#  ('ENSMUSG00000052337',
#   'ENSMUST00000064062',
#   'Mitofilin',
#   '6e-206',
#   '43',
#   '745'),
#  ('ENSMUSG00000061904',
#   'ENSMUST00000170810',
#   'Mito_carr',
#   '2.4e-19',
#   '66',
#   '145'),
#  ('ENSMUSG00000061904',
#   'ENSMUST00000170810',
#   'Mito_carr',
#   '1.2e-17',
#   '161',
#   '243'),
#  ('ENSMUSG00000061904',
#   'ENSMUST00000170810',
#   'Mito_carr',
#   '7.9e-09',
#   '258',
#   '336'),
#  ('ENSMUSG00000061904',
#   'ENSMUST00000164505',
#   'Mito_carr',
#   '7.3e-20',
#   '65',
#   '144'),
#  ('ENSMUSG00000061904',
#   'ENSMUST00000164505',
#   'Mito_carr',
#   '1.2e-17',
#   '160',
#   '242'),
#  ('ENSMUSG00000061904',
#   'ENSMUST00000164505',
#   'Mito_carr',
#   '7.8e-09',
#   '257',
#   '335'),
#  ('ENSMUSG00000061904',
#   'ENSMUST00000076694',
#   'Mito_carr',
#   '7.3e-20',
#   '65',
#   '144'),
#  ('ENSMUSG00000061904',
#   'ENSMUST00000076694',
#   'Mito_carr',
#   '1.2e-17',
#   '160',
#   '242'),
#  ('ENSMUSG00000061904',
#   'ENSMUST00000076694',
#   'Mito_carr',
#   '7.8e-09',
#   '257',
#   '335'),
#  ('ENSMUSG00000024359',
#   'ENSMUST00000025217',
#   'HSP70',
#   '6.2e-270',
#   '55',
#   '652'),
#  ('ENSMUSG00000072849',
#   'ENSMUST00000122229',
#   'Serpin',
#   '3.5e-117',
#   '49',
#   '410'),
#  ('ENSMUSG00000072849',
#   'ENSMUST00000085054',
#   'Serpin',
#   '3.5e-117',
#   '49',
#   '410'),
#  ('ENSMUSG00000018893', 'ENSMUST00000166179', 'Globin', '8.4e-22', '7', '112'),
#  ('ENSMUSG00000018893', 'ENSMUST00000229125', 'Globin', '9.6e-17', '7', '79'),
#  ('ENSMUSG00000018893', 'ENSMUST00000229423', 'Globin', '8.4e-22', '7', '112'),
#  ('ENSMUSG00000018893', 'ENSMUST00000169226', 'Globin', '8.4e-22', '7', '112'),
#  ('ENSMUSG00000018893', 'ENSMUST00000019037', 'Globin', '8.4e-22', '7', '112'),
#  ('ENSMUSG00000018893', 'ENSMUST00000230031', 'Globin', '4.8e-07', '1', '57'),
#  ('ENSMUSG00000069917', 'ENSMUST00000093207', 'Globin', '4.5e-29', '7', '107'),
#  ('ENSMUSG00000069919', 'ENSMUST00000093209', 'Globin', '4.5e-29', '7', '107')]

# %%
','.join(df[qcol].drop_duplicates().to_list())

# %%
r = requests.post('https://rest.uniprot.org/idmapping/run', {'from':'UniProtKB_AC-ID', 'to':'Ensembl', 'ids':','.join(df[qcol].drop_duplicates().to_list())})

# %%
r.json()['jobId']
# Out:
# 'c66f27cd4439339158c95f5cb3945e6bdf75ffc9'

# %%
r2 = requests.get(f'https://rest.uniprot.org/idmapping/stream/{r.json()["jobId"]}?compressed=false&format=json')

# %%
r2.ok
# Out:
# False

# %%
r2.json()
# Out:
# {'url': 'http://rest.uniprot.org/idmapping/stream/c66f27cd4439339158c95f5cb3945e6bdf75ffc9',
#  'messages': ['Resource not found']}

# %%
df['q'].drop_duplicates().to_list()
# Out:
# ['P62342',
#  'P28665',
#  'Q9CZ13',
#  'Q8CAQ8',
#  'G5E902',
#  'P38647',
#  'Q00898',
#  'P04247',
#  'Q91VB8',
#  'Q8BH95',
#  'Q99KI0',
#  'Q9WUM5',
#  'P23242',
#  'Q9QY93',
#  'Q8BW75',
#  'P19536',
#  'P10649',
#  'A2A439',
#  'A0A0R4J0I1',
#  'P56480',
#  'P23953',
#  'Q8QZS1',
#  'Q9CRB9',
#  'A2AL85',
#  'Q3TA68',
#  'P12787',
#  'A0A0R4J0X7',
#  'A8DUK4',
#  'Q03265',
#  'Q9ERI2',
#  'O35943',
#  'Q9CXW2',
#  'Q5SUC9',
#  'P70404',
#  'O35459',
#  'Q8K370',
#  'Q9DCB8',
#  'E9QPD7',
#  'P07310',
#  'A6ZI44',
#  'Q8CC88',
#  'Q9DCM0',
#  'Q60936',
#  'P99024',
#  'Q8BIJ6',
#  'Q80Y14',
#  'Q9JHI5',
#  'Q9D0S9',
#  'Q6P1F6',
#  'P47857',
#  'O88492',
#  'P17182',
#  'P48962',
#  'P08249',
#  'Q9D1A2',
#  'Q9CQZ5',
#  'P08228',
#  'P21614',
#  'Q99JY0',
#  'Q91ZA3',
#  'P07724',
#  'P20152',
#  'P19096',
#  'O35129',
#  'P45952',
#  'O35639',
#  'P60710',
#  'Q9JI91',
#  'Q9D020',
#  'P70670',
#  'Q9Z0V7',
#  'J3QMG3',
#  'Q8K411',
#  'P62141',
#  'Q8CG76',
#  'P70398',
#  'Q9CPV4',
#  'Q9WUB3',
#  'A0A0R4J083',
#  'Q8K2B3',
#  'P07309',
#  'Q9D328',
#  'Q9DCW4',
#  'Q60932',
#  'P48787',
#  'O35887',
#  'Q8R4N0',
#  'P35564',
#  'P63017',
#  'A2AKU9',
#  'P16125',
#  'P30416',
#  'Q9Z1P6',
#  'P63038',
#  'Q8R1S0',
#  'E9PV24',
#  'Q8VHX6',
#  'A2A513',
#  'Q8BH35',
#  'E9QP49',
#  'O88569',
#  'O09131',
#  'P54071',
#  'O08528',
#  'P99028',
#  'Q8BWT1',
#  'B1AU25',
#  'P08113',
#  'P01027',
#  'Q9WTQ5',
#  'Q64727',
#  'Q9D0M3',
#  'F8VQJ3',
#  'Q8BMF4',
#  'Q9CZ44',
#  'P17751',
#  'Q9Z2I9',
#  'O09111',
#  'J3QQ13',
#  'A3KMP2',
#  'Q9D172',
#  'E9Q6U4',
#  'Q60597',
#  'P20108',
#  'Q60864',
#  'F8VPK5',
#  'Q9EQH3',
#  'Q8BI55',
#  'Q9JHU4',
#  'P35980',
#  'P24369',
#  'Q99LX0',
#  'Q9D7N3',
#  'Q8BGC4',
#  'O70250',
#  'A0A140LIU4',
#  'Q9D6J6',
#  'Q6IME9',
#  'A0A1B0GX27',
#  'P50544',
#  'Q99LC5',
#  'Q1ERP8',
#  'Q8BH59',
#  'A0A0J9YUB6',
#  'Q9CZU6',
#  'P58252',
#  'Q9Z2K1',
#  'D3Z7Q3',
#  'Q63836',
#  'E9Q828',
#  'A2AEW8',
#  'P24270',
#  'Q78IK4',
#  'P58771',
#  'E9Q616',
#  'P07901',
#  'Q91WK2',
#  'Q3TCD4',
#  'H3BJQ7',
#  'A0A0J9YUD8',
#  'Q9JJW5',
#  'Q91X72',
#  'P05213',
#  'Q9QYG0',
#  'Q9JI39',
#  'P40124',
#  'Q9EPL8',
#  'Q8C0C3',
#  'A0A0R4J293',
#  'Q9CQV8',
#  'P09671',
#  'Q9DA03',
#  'Q99KQ4',
#  'Q9DB20',
#  'G3X9L6',
#  'P14869',
#  'H3BJL6',
#  'Q8BFR5',
#  'Q923D2',
#  'O70361',
#  'O09044',
#  'Q06770',
#  'A0A075B5P3',
#  'Q7TQK5',
#  'F6VW30',
#  'Q8CDN6',
#  'Q8K0D5',
#  'O55143',
#  'P05201',
#  'Q5EBG6',
#  'P97807',
#  'Q9D7A8',
#  'Q9D892',
#  'Q8K157',
#  'H7BX22',
#  'E9QN70',
#  'A0A0N4SUH8',
#  'P50446',
#  'Q00623',
#  'Q921G7',
#  'Q149B8',
#  'Q6P8J7',
#  'Q9CR62',
#  'P09411',
#  'P05202',
#  'Q05186',
#  'Q60675',
#  'P68134',
#  'Q14BI5',
#  'P04919',
#  'G3UXZ5',
#  'P52480',
#  'Q8R429',
#  'P11499',
#  'O55029',
#  'Q04447',
#  'Q3U3G8',
#  'P32020',
#  'Q8BRK8',
#  'P47199',
#  'P80315',
#  'D3Z7P3',
#  'Q9JK42',
#  'Q6ZQ73',
#  'P04104',
#  'Q8JZQ2',
#  'Q9CQ69',
#  'B8JJE0',
#  'P14152',
#  'A0A0A0MQF6',
#  'Q3URS9',
#  'P62192',
#  'P42932',
#  'D3Z0V7',
#  'Q791V5',
#  'A3KGU7',
#  'Q06185',
#  'Q9D404',
#  'E0CXA9',
#  'P17879',
#  'B7FAU9',
#  'F8VPN4',
#  'E0CZ78',
#  'G3UXX3',
#  'Q924X2',
#  'E9Q7L0',
#  'Q9CQB4',
#  'G3UVV4',
#  'Q9D051',
#  'A2AMM0',
#  'O35226',
#  'Q02566',
#  'Q9ESL4',
#  'Q7TQ48',
#  'P10493',
#  'Q9DB15',
#  'P45376',
#  'Q9D2G2',
#  'A0A0A0MQA3',
#  'Q91VM9',
#  'Q9JLV1',
#  'Q62165',
#  'E9Q035',
#  'O08553',
#  'P26645',
#  'Q7TQ95',
#  'Q9ET78',
#  'P70296',
#  'Q9CR61',
#  'Q1XH17',
#  'O35344',
#  'Q07417',
#  'O55126',
#  'Q8BZF8',
#  'Q8BMS1',
#  'P40142',
#  'P40336',
#  'Q05816',
#  'G5E850',
#  'P62897',
#  'A0A140T8V1',
#  'D3YYK8',
#  'Q9Z1J3',
#  'P50462',
#  'Q9CQ62',
#  'Q9JKS4',
#  'Q5XJF6',
#  'A0A0A6YX73',
#  'P62983',
#  'A0A087WS46',
#  'A0A0R4J039',
#  'P56565',
#  'P54726',
#  'Q9Z2Z6',
#  'Q71RI9',
#  'Q4LDF6',
#  'Q9Z2I0',
#  'Q8VDN2',
#  'Q8BKZ9',
#  'A2ASS6',
#  'P34914',
#  'H3BJN7',
#  'Q6P9R2',
#  'E9Q9C0',
#  'F6U775',
#  'Q3U2G2',
#  'A2AEX6',
#  'B1B0C7',
#  'E9Q9T8',
#  'Q9D819',
#  'Q8R1I1',
#  'P50396',
#  'Q91VA7',
#  'P61982',
#  'P55264',
#  'G3UX26',
#  'Q6ZWX6',
#  'E9Q8P0',
#  'P0C605',
#  'P06745',
#  'G3X977',
#  'Q62261',
#  'O55023',
#  'F7BCD5',
#  'O54988',
#  'D3YUM1',
#  'P62334',
#  'E9QQ93',
#  'Q9Z1Z2',
#  'Q9WU78',
#  'P47791',
#  'Q8BP92',
#  'Q3UPL0',
#  'E9Q8H9',
#  'E9PZF0',
#  'Q8K1R7',
#  'A0A0R4J038',
#  'Q9DCJ5',
#  'Q99LC3',
#  'A0A0R4J1E2',
#  'P62908',
#  'Q9R0Y5',
#  'P50580',
#  'Q8R5L1',
#  'Q76MZ3',
#  'Q6P3A8',
#  'Q3V384',
#  'Q9DB73',
#  'A2AN08',
#  'P19783',
#  'D3YU12',
#  'D3YU22',
#  'Q00897',
#  'Q9WUZ7',
#  'P52825',
#  'O08749',
#  'H3BJ37',
#  'G5E924',
#  'P51150',
#  'Q06890',
#  'Q9D8Z2',
#  'E9PUE8',
#  'A0A0R4J093',
#  'Q8CHT0',
#  'Q9EQ20',
#  'G3X8Y3',
#  'Q9DB77',
#  'A0A0R4J1N7',
#  'Q61768',
#  'P48036',
#  'E9PZD8',
#  'D3YYT0',
#  'P09405',
#  'P42125',
#  'G5E8J6',
#  'Q9Z2M7',
#  'Q62418',
#  'B1ARU4',
#  'P54822',
#  'F6SFF5',
#  'P97927',
#  'P46460',
#  'A0A0R4J140',
#  'O88342',
#  'Q9D3D9',
#  'A0A140LHG8',
#  'Q8JZN5',
#  'Q62523',
#  'Q91VD9',
#  'Q9D1H8',
#  'G5E8R7',
#  'P21981',
#  'P62281',
#  'A2CG35',
#  'A0A1B0GRV0',
#  'Q3UDM0',
#  'S4R1S2',
#  'A0A0R4J081',
#  'Q8R2G4',
#  'Q9CQ60',
#  'P02088',
#  'P47738',
#  'Q8BMK4',
#  'P35235',
#  'Q6GT24',
#  'Q8QZT1',
#  'Q9CR68',
#  'P68040',
#  'P80318',
#  'Q99MR8',
#  'P21550',
#  'Q9CPQ8',
#  'Q3TL44',
#  'A0A1D5RMC8',
#  'P97429',
#  'Q91VK1',
#  'A0A087WQ94',
#  'Q921H9',
#  'A0A1L1STE6',
#  'P18872',
#  'Q7TSG2',
#  'Q5SRX1',
#  'A0A0R4J0P1',
#  'P26443',
#  'P26039',
#  'Q58A65',
#  'A0A075B5P2',
#  'J3QMM7',
#  'F8WIT2',
#  'Q9CPY7',
#  'P56812',
#  'P62918',
#  'Q9CPP6',
#  'Q6IRU5',
#  'A0A0R4J049',
#  'O89053',
#  'P53986',
#  'Q8R1Q8',
#  'Q922B2',
#  'P60229',
#  'E9QQ25',
#  'P20029',
#  'Q59J78',
#  'Q5SXR6',
#  'Q9CQC7',
#  'Q60605',
#  'A0A1B0GSX0',
#  'Q9CR16',
#  'Q922U2',
#  'P31001',
#  'Q5SX39',
#  'P56391',
#  'E9PWZ3',
#  'O35857',
#  'P24527',
#  'S4R2R5',
#  'E9QM90',
#  'Q9QXX4',
#  'O70400',
#  'A0A0U1RPI1',
#  'Q99KR3',
#  'P08905',
#  'E9Q557',
#  'E9QPX3',
#  'Q6ZQ38',
#  'Q61249',
#  'Q8BKC5',
#  'Q9R0Q6',
#  'A0A1L1SVG6',
#  'Q3B7Z2',
#  'H7BX01',
#  'Q923G2',
#  'B2M1R6',
#  'A0A0G2JDW2',
#  'E9Q6B6',
#  'Q9R0P5',
#  'Q08857',
#  'Q02053',
#  'P52503',
#  'E9Q401',
#  'Q9D880',
#  'O88531',
#  'P00416',
#  'Q99PR8',
#  'Q6P2B1',
#  'P19324',
#  'Q9CQQ7',
#  'Q8BUY5',
#  'G3X9J1',
#  'Q5SS83',
#  'Q61655',
#  'G3X8U3',
#  'Q3TMH2',
#  'Q91YH5',
#  'P09103',
#  'Q61941',
#  'P80313',
#  'Q7TQI3',
#  'P56375',
#  'P35700',
#  'P48758',
#  'A0A0A0MQD2',
#  'Q9CX34',
#  'Q6PB66',
#  'E9PVC5',
#  'Q63918',
#  'D3Z3A0',
#  'O54724',
#  'Q9Z2I8',
#  'Q99KF1',
#  'Q8BLY2',
#  'A0A0R3P9C8',
#  'E9QLJ0',
#  'Q922Y1',
#  'Q3U3J1',
#  'A2AFQ0',
#  'Q91WS0',
#  'Q6IFX2',
#  'P28654',
#  'Q6XPS7',
#  'Q2TPA8',
#  'Q61699',
#  'Q99LY9',
#  'A0A0R4J275',
#  'D3Z4J9',
#  'P70663',
#  'Q63850',
#  'Q99N87',
#  'Q3THG9',
#  'Q8BGA9',
#  'Q9D0F9',
#  'P53395',
#  'Q8R238',
#  'Q61171',
#  'Q3UE92',
#  'Q61074',
#  'Q9WTP7',
#  'P16045',
#  'F8WID5',
#  'Q62234',
#  'A2A998',
#  'Q9EQS3',
#  'Q8JZL3',
#  'A6H644',
#  'Q8BP40',
#  'J3QN89',
#  'Q91YQ5',
#  'D3YVP5',
#  'Q9ERI6',
#  'P06801',
#  'Q91YR1',
#  'G3UXW9',
#  'F7CBP1',
#  'Q9R069',
#  'P30115',
#  'Q921H8',
#  'B2RSU7',
#  'P10605',
#  'Q8VBZ3',
#  'Q08879',
#  'Q8VBT1',
#  'P50171',
#  'Q3TML0',
#  'O08715',
#  'A0A1B0GQZ1',
#  'Q9JKB3',
#  'A0A1B0GRJ5',
#  'Q91ZJ5',
#  'Q9CZR8',
#  'Q3V3R4',
#  'Q99M01',
#  'P29341',
#  'O54734',
#  'A0A1B0GT63',
#  'Q9QUM9',
#  'Q8BH55',
#  'Q3TKD0',
#  'Q9QZB9',
#  'P60843',
#  'F8WIK0',
#  'P38060',
#  'Q61599',
#  'Q61838',
#  'P14148',
#  'Q6NT99',
#  'P13020',
#  'Q9DCZ4',
#  'P09055',
#  'O88696',
#  'O08529',
#  'G5DDB7',
#  'A0A0G2JFY5',
#  'Q9D0L4',
#  'P83917',
#  'Q6IRU2',
#  'P23198',
#  'O35215',
#  'G3X9U9',
#  'A0A1B0GT92',
#  'O35685',
#  'F8WIA1',
#  'E9Q3M3',
#  'Q3UHX2',
#  'Q9WTP6',
#  'P97450',
#  'Q8CGC7',
#  'P57780',
#  'Q9DBF1',
#  'Q8K1M6',
#  'E9PV12',
#  'A0A1D5RLY6',
#  'Q61598',
#  'A0A0A6YXL6',
#  'G3XA10',
#  'Q91W50',
#  'Q9CQN1',
#  'P04117',
#  'Q921I1',
#  'P08032',
#  'E9Q1G8',
#  'O09061',
#  'P07356',
#  'Q9QXT0',
#  'Q8BMF3',
#  'Q62446',
#  'Q61216',
#  'Q8VDC0',
#  'A0A140LIF0',
#  'Q9CXI0',
#  'D3YYB1',
#  'Q99LD8',
#  'D3Z6I8',
#  'Q99P30',
#  'E9PVP0',
#  'Q9QUR6',
#  'P29699',
#  'Q9DBG3',
#  'G3X972',
#  'Q8BH78',
#  'Q9CZW5',
#  'P15327',
#  'A2AVJ7',
#  'E9Q8T1',
#  'P51885',
#  'Q01853',
#  'Q8VDK1',
#  'Q9R1P4',
#  'A2BFF5',
#  'E9Q7K1',
#  'Q9WVE8',
#  'Q61425',
#  'A0A1B0GSG5',
#  'E9Q1J7',
#  'Q3TYX3',
#  'Q6YJU1',
#  'Q60994',
#  'Q3THS6',
#  'Q8R1G2',
#  'Q3U276',
#  'A0A0R4IZY0',
#  'Q91XD6',
#  'Q8BYM8',
#  'O70622',
#  'Q8CI94',
#  'P53702',
#  'P14685',
#  'P62962',
#  'P63024',
#  'A2ATI9',
#  'P42703',
#  'Q9CY64',
#  'D3Z7Q2',
#  'Q91YP0',
#  'P62196',
#  'Q9D8S9',
#  'P56399',
#  'Q9WVK4',
#  'P29788',
#  'Q9DB05',
#  'D3Z7V3',
#  'A2A8E2',
#  'D3YY36',
#  'Q80ZS3',
#  'Q8R086',
#  'Q9CQR4',
#  'Q9D1M0',
#  'O88544',
#  'Q99L13',
#  'P27612',
#  'Q9JI75',
#  'P62320',
#  'A2AQR0',
#  'Q99MR9',
#  'P49182',
#  'P58871',
#  'Q8BGQ7',
#  'Q9JII6',
#  'P19221',
#  'P56695',
#  'H3BLR8',
#  'P51125',
#  'Q8BH64',
#  'F7AI87',
#  'D3Z487',
#  'E9PXY8',
#  'P15626',
#  'Q8VCT3',
#  'Q8VDM4',
#  'Q9CQA3',
#  'Q11011',
#  'A0A140LHT6',
#  'D3Z5G7',
#  'A3KFX0',
#  'Q8JZQ9',
#  'K3W4Q8',
#  'D3Z316',
#  'O35295',
#  'Q64010',
#  'Q01279',
#  'Q9DBJ1',
#  'Q9JMA1',
#  'A0A0B4J1E7',
#  'Q99NB1',
#  'D9J302',
#  'Q3UMP4',
#  'Q9Z0Y1',
#  'Q9D5T0',
#  'A2A6Q8',
#  'Q920A7',
#  'Q9ERK4',
#  'Q5XJY5',
#  'E9Q5L3',
#  'O70433',
#  'Q6ZWZ7',
#  'Q9D1D4',
#  'P35979',
#  'Q3TCH7',
#  'O88844',
#  'A0A0R4J137',
#  'Q8CIB5',
#  'P26231',
#  'A0A0A0MQC7',
#  'F2Z3X6',
#  'Q9ES46',
#  'G3UW82',
#  'Q8QZY1',
#  'A2AU62',
#  'Q9WVB0',
#  'Q9R1Q7',
#  'Q8BLF1',
#  'A2AF82',
#  'Q8K2C6',
#  'A0A087WR45',
#  'Q9JKC6',
#  'B7ZNL2',
#  'G3X8R0',
#  'Q8BG32',
#  'P11983',
#  'A2AWI7',
#  'Q9QYB1',
#  'P49222',
#  'Q923T9',
#  'E9QKL6',
#  'Q69ZW3',
#  'A0A0G2JGS4',
#  'Z4YKV1',
#  'Q8BHL3',
#  'Q99JI4',
#  'Q61081',
#  'A0A0N4SVQ1',
#  'Q80YC5',
#  'A0A087WQY7',
#  'Q8BWW3',
#  'Q8R2P8',
#  'Q9Z1T1',
#  'Q9CR24',
#  'Q3ULD5',
#  'Q8R2U6',
#  'P62874',
#  'Q9Z2X1',
#  'Q9DCM2',
#  'Q9Z0P4',
#  'A0A0A0MQG1',
#  'Q5RKN9',
#  'D3Z125',
#  'Q8BMS4',
#  'E9PV58',
#  'P50247',
#  'A0A087WS16',
#  'Q78J03',
#  'Q9CQ75',
#  'F8WHU8',
#  'Q01339',
#  'P63005',
#  'Q9DBB8',
#  'Q9CQL5',
#  'P03899',
#  'Q924T2',
#  'A2ATR8',
#  'Q8VDC1',
#  'E9PV48',
#  'E9QJW0',
#  'Q9D6J5',
#  'Q9D8B3',
#  'Q8VDU5',
#  'P97855',
#  'P63101',
#  'Q6NSR8',
#  'F7ARZ1',
#  'P05125',
#  'Q64444',
#  'A0A1L1SRX2',
#  'E0CXN5',
#  'Q9EQI5',
#  'P56380',
#  'E9PUQ5',
#  'Q6PHN9',
#  'Q9D8U8',
#  'P67778',
#  'Q8R1X6',
#  'E9PYB0',
#  'P01029',
#  'Q61586',
#  'Q8BJU0',
#  'D3YUV1',
#  'A2AHX7',
#  'A0A0R4J0I6',
#  'Q8BGX2',
#  'Q9DAU1',
#  'P61089',
#  'P60335',
#  'Q8VE88',
#  'Q99J39',
#  'Q80X90',
#  'P50516',
#  'A0A0G2JDR6',
#  'P99027',
#  'O08532',
#  'Q9D358',
#  'D3YXK2',
#  'A0A1D5RLS1',
#  'Q9CQN7',
#  'Q922B1',
#  'P35278',
#  'Q9D2M8',
#  'Q8VE95',
#  'Q3UER8',
#  'Q9QUI0',
#  'P26041',
#  'Q8VCA8',
#  'E9PZS8',
#  'P68510',
#  'P46935',
#  'Q9CYT6',
#  'Q99PT1',
#  'Q9QYR9',
#  'E9QNR6',
#  'E9Q715',
#  'O55100',
#  'Q9DCS3',
#  'P51667',
#  'A2AJW4',
#  'P62204',
#  'Q9D6K8',
#  'P58774',
#  'O08547',
#  'A0A0R4J139',
#  'Q71FD7',
#  'O70439',
#  'Q8CI08',
#  'A0A0N4SW94',
#  'P10107',
#  'A0A087WP14',
#  'Q9DCL9',
#  'E9Q397',
#  'Q1W617',
#  'Q810B6',
#  'Q9DCN1',
#  'P15105',
#  'Q9CQX2',
#  'B2KGR2',
#  'Q64737',
#  'E9QMK9',
#  'P53811',
#  'Q78IK2',
#  'Q9QWL7',
#  'Q99LB2',
#  'Q9D0K2',
#  'Q8K010',
#  'Q3U0B3',
#  'Q3THK7',
#  'Q3UFY8',
#  'Q8BWF0',
#  'Q99KK7',
#  'Q8CIE6',
#  'Q02257',
#  'Q80YV4',
#  'P06728',
#  'Q9JIF7',
#  'P10630',
#  'P03930',
#  'H3BJA3',
#  'Q9WUR9',
#  'P35441',
#  'A0A0N4SUN3',
#  'F8WJ05',
#  'Q9Z1A1',
#  'Q80TM9',
#  'Q61292',
#  'B7ZCI2',
#  'P54731',
#  'D3YWZ1',
#  'D3YZN4',
#  'B9EHJ3',
#  'Q61646',
#  'P23927',
#  'Q8K0E8',
#  'Q6ZQI3',
#  'Q8BK03',
#  'Q8C5H8',
#  'P16332',
#  'Q91VH6',
#  'Q9JJV2',
#  'O08797',
#  'E9QAQ5',
#  'D3Z4J1',
#  'Q9ET54',
#  'P28653',
#  'Q9CQF6',
#  'Q8CC86',
#  'A2BE93',
#  'A2AKD7',
#  'P08752',
#  'Q8BFS6',
#  'H7BX88',
#  'P62071',
#  'P80316',
#  'A0A0U1RQ27',
#  'P51859',
#  'Q9DCT1',
#  'O35643',
#  'Q8R2K3',
#  'Q920Q8',
#  'Q8K1B8',
#  'E9PYG9',
#  'D3YYN7',
#  'Q91WU5',
#  'Q80ZJ6',
#  'P68372',
#  'E9QAT9',
#  'Q62264',
#  'H7BX95',
#  'F6SVV1',
#  'Q9DCV4',
#  'O35127',
#  'B1AUQ7',
#  'A0A0R4J0R1',
#  'P70441',
#  'Q80YD1',
#  'Q8VIM9',
#  'Q99LP6',
#  'Q3UMU9',
#  'Q8CGK3',
#  'Q6NVE9',
#  'P10126',
#  'E9Q3P9',
#  'P10518',
#  'Q99JI6',
#  'Q80XN0',
#  'Q9QXS1',
#  'Q61578',
#  'Q99M87',
#  'P59017',
#  'Q3UN02',
#  'O55234',
#  'Q99KV1',
#  'P00920',
#  'B7ZBY7',
#  'P26043',
#  'P27773',
#  'D3YVW2',
#  'Q04519',
#  'Q3UV17',
#  'P80314',
#  'Q9DCZ1',
#  'P62827',
#  'Q8VCI5',
#  'Q9D1C8',
#  'E9QN41',
#  'E9QAS7',
#  'Q3TG45',
#  'Q99L45',
#  'A0A0U1RP30',
#  'Q8BGD9',
#  'O35382',
#  'Q8QZR5',
#  'B1AR13',
#  'O54950',
#  'E9Q4B5',
#  'Q64514',
#  ...]
